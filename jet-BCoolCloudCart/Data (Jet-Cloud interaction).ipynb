# %%
import numpy as np
#import pyPLUTO as pp
from astropy.io import ascii
import os
import sys
from ipywidgets import interactive, widgets,fixed
from IPython.display import Audio, display
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.gridspec as gridspec
import matplotlib.ticker as ticker
from matplotlib.animation import FuncAnimation,FFMpegWriter
from matplotlib import rc,rcParams
from scipy.integrate import quad
rc('text', usetex=True)
rcParams['figure.figsize'] = (17., 14.0)
rcParams['ytick.labelsize'],rcParams['xtick.labelsize'] = 17.,17.
rcParams['axes.labelsize']=19.
rcParams['legend.fontsize']=17.
rcParams['text.latex.preamble'] = ['\\usepackage{siunitx}']
# import seaborn
# seaborn.despine()
# seaborn.set_style('white', {'axes.linewidth': 0.5, 'axes.edgecolor':'black'})
# seaborn.despine(left=True)
import importlib

# %%
#test0=np.load('../test0/test0.npz')
test5=np.load('test5.npz')

# %%
rcParams['figure.figsize'] = (22,22)

# %%
test5['RHO'][-1].shape
# Out:
# (768, 640)

# %%
plt.plot(test1['Y'],np.log10(test1['RHO'][-1,:,400]))

# %%
plt.contourf(test5['X'],test5['Y'],np.log10(test5['RHO'][-1,:,:]),cmap='jet',levels=np.linspace(-7,5,13))
plt.colorbar()
plt.xlim(0,7)
plt.ylim(20,40)
# Out:
# (20, 40)

# %%
plt.contourf(test5['X'],test5['Y'],np.log10(test5['TMP'][-1,:,:]),cmap='jet',levels=np.linspace(0,16,17))
plt.colorbar()
plt.xlim(0,7)
plt.ylim(20,40)
# Out:
# (20, 40)

# %%
PU=test5['PU']

# %%
PU
# Out:
# array({'rho': <Quantity 1.67e-24 g / cm3>, 'vx1': <Quantity 2.99792458e+10 cm / s>, 'vx2': <Quantity 2.99792458e+10 cm / s>, 'vx3': <Quantity 2.99792458e+10 cm / s>, 'Bx1': <Quantity 0.13733583 G>, 'Bx2': <Quantity 0.13733583 G>, 'Bx3': <Quantity 0.13733583 G>, 'prs': <Quantity 0.00150092 Ba>, 'tmp': <Quantity 1.08881991e+13 K>, 'T': <Quantity 1.02927125e+09 s>, 'L': <Quantity 3.08567758e+19 cm>},
#       dtype=object)

# %%
gamma=1./(1.-(test5['Vz']**2+test5['Vr']**2+test5['Vphi']**2))

# %%
V=np.sqrt(test5['Vz']**2+test5['Vr']**2+test5['Vphi']**2)

# %%
V.max()
# Out:
# 0.9685233128571884

# %%
plt.contourf(test5['X'],test5['Y'],np.sqrt(test5['Vz'][70,:,:]**2+test5['Vr'][70,:,:]**2+test5['Vphi'][70,:,:]**2),cmap='jet')#,levels=np.linspace(0,16,17))
plt.colorbar()
plt.xlim(0,4)
plt.ylim(20,40)
# Out:
# (20, 40)

# %%
gamma.shape
# Out:
# (114, 768, 640)

# %%
gamma[:,:,:].max()
# Out:
# 16.13876954506792

# %%
plt.contourf(test5['X'],test5['Y'],gamma[-1,:,:],cmap='jet',levels=np.arange(0,17,0.25))
plt.colorbar()
plt.xlim(0,2.)
#plt.ylim(20,40)

# %%
plt.contourf(test5['X'],test5['Y'],np.log10(np.abs(test5['Bphi'][-1,:,:])),cmap='jet',levels=np.arange(-4,-2,0.25))
plt.colorbar()
plt.contour(test5['X'],test5['Y'],gamma[-1,:,:],cmap='jet',levels=np.arange(0,17,0.5))

plt.xlim(0,2.)
#plt.ylim(20,40)
# Out:
# /home/astromix/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log10
#   """Entry point for launching an IPython kernel.
# (0, 2.0)

# %%
sigma=test1['Bphi']**2/(gamma**2*test1['RHO'])

# %%
plt.contourf(test1['X'],test1['Y'],2*np.log10(sigma[-1,:,:]),cmap='jet',levels=np.linspace(-50,0,17))
plt.colorbar()
plt.xlim(0,4)
plt.ylim(20,40)
# Out:
# /home/astromix/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log10
#   """Entry point for launching an IPython kernel.
# (20, 40)

# %%
plt.contourf(test1['X'],test1['Y'],2*np.log10(test1['Bphi'][-1,:,:]),cmap='jet',levels=np.linspace(-10,0,17))
plt.colorbar()
plt.xlim(0,4)
plt.ylim(20,40)
# Out:
# /home/astromix/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log10
#   """Entry point for launching an IPython kernel.
# /home/astromix/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in log10
#   """Entry point for launching an IPython kernel.
# (20, 40)

# %%
importlib.reload(f)
f.quadruple(test1,np.log10(test1['RHO']),rows=2,cols=3,tdk='yrs',Save_Figure='',scale=(6,10),color='jet',zlim=[-1,3])

# %%
test1['T']
# Out:
# array([   0.       ,  158.356716 ,  316.9646545,  475.330722 ,
#         633.988588 ,  792.330722 ,  950.826284 , 1109.422335 ,
#        1267.927724 , 1426.388416 , 1584.825333 , 1743.433113 ])

# %%
importlib.reload(f)
f.quadruple(test1,np.log10(test1['RHO']),rows=2,cols=3,tdk='yrs',color='jet',scale=(6,10),zlim=[-1,3])

# %%
beta=test1['PRS']/test1['Bz']**2
# Out:
# /home/astromix/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in true_divide
#   """Entry point for launching an IPython kernel.
# /home/astromix/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: overflow encountered in true_divide
#   """Entry point for launching an IPython kernel.

# %%
beta.min(),beta.max()
# Out:
# (0.01692044541346114, inf)

# %%
rcParams['figure.figsize'] = (12,22)
T=-1
#plt.contourf(np.log10(test1['RHO'][:,:,T]).T,origin='lower',cmap='Greys',levels=np.linspace(-3,5,50))
plt.contourf(np.log10(test1['TMP'][:,:,T]).T,origin='lower',cmap='jet',levels=np.linspace(2,15,100))
plt.contour(test1['Bz'][:,:,T].T**2,origin='lower',linewidth=7)
plt.contour(test1['PRS'][:,:,T].T**2,origin='lower',linestyles='--',linewidth=7)
plt.xlim(0,150)
plt.ylim(100,300)
# Out:
# (100, 300)

# %%
rcParams['figure.figsize'] = (12,22)
plt.contourf(test1['Bz'][:,:,-1].T**2,origin='lower',cmap='Greys')
plt.contour(np.log10(test1['RHO'][:,:,-1]).T,origin='lower',linewidth=5,levels=np.linspace(-2,3,3))

# %%
f.quadruple(test1,test1['Bz']**2,rows=2,cols=3,color='Greys',scale=(6,10),tdk='yrs',Save_Figure='')

# %%
test1['Vy'].shape
# Out:
# (512, 1024, 30)

# %%
f.quadruple(test1,np.log10(np.sqrt(test1['Vy']**2+test1['Vx']**2)),rows=2,cols=3,color='jet',scale=(6,15),tdk='kyrs',zlim=[-10,0],Save_Figure='beta')
# Out:
# /home/astromix/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log10
#   """Entry point for launching an IPython kernel.

# %%
f.quadruple(test1,np.log10(beta),rows=2,cols=3,color='jet',scale=(6,10),tdk='yrs',zlim=[-5,5],Save_Figure='beta')

# %%
f.quadruple(test1,np.log10(test1['PRS']),rows=2,cols=3,tdk='yrs')

# %%
test1['Bz'].shape
# Out:
# (512, 1024, 30)

# %%
rcParams['figure.figsize'] = (12,12)
plt.plot(test1['Bz'][:,0,1]**2)
plt.plot(test1['PRS'][:,0,1])
#plt.plot(test1['X'][:],test1['Bz'][:,40,1]**2)
#plt.plot(test1['X'][:],test1['Bz'][:,50,1]**2)
plt.yscale('log')
plt.ylim(1e-10,1e-1)
plt.xlim(0,100)
# Out:
# (0, 100)

# %%
rcParams['figure.figsize'] = (12,12)
plt.plot(test1['X'][:],test1['Bz'][:,0,1]**2)
plt.plot(test1['X'][:],test1['PRS'][:,0,1])
#plt.plot(test1['X'][:],test1['Bz'][:,40,1]**2)
#plt.plot(test1['X'][:],test1['Bz'][:,50,1]**2)
plt.yscale('log')
plt.ylim(1e-10,1e-1)
# Out:
# (1e-10, 0.1)

# %%
plt.plot(test1['X'][:],np.log10(beta[:,1,2]),'--')
plt.ylim(-2,2)
# Out:
# (-2, 2)

# %%
rcParams['figure.figsize'] = (12,12)
plt.plot(test1['X'][:],test1['Bz'][:,0,1]**2)
plt.plot(test1['X'][:],test1['PRS'][:,0,1])
#plt.plot(test1['X'][:],test1['Bz'][:,50,1]**2)
plt.yscale('log')
plt.ylim(1e-10,1e-1)
# Out:
# (1e-10, 0.1)

# %%
plt.plot(test1['X'][:],test1['Bz'][:,0,1])
# plt.plot(test1['X'][:],test1['Bz'][:,40,1])
# plt.plot(test1['X'][:],test1['Bz'][:,50,1])
#plt.yscale('log')

# %%
np.log10(test1['TMP'].max())
# Out:
# 23.39781463379187

# %%
plt.plot(test1['X'][:],test1['TMP'][:,0,0])
plt.plot(test1['X'][:],test1['TMP'][:,100,3])
#plt.plot(test1['X'][:],test1['TMP'][:,0,-1])
plt.yscale('log')

# %%
plt.plot(test1['X'][:],test1['TMP'][:,0,0])
plt.plot(test1['X'][:],test1['TMP'][:,300,3])
#plt.plot(test1['X'][:],test1['TMP'][:,0,-1])
plt.yscale('log')

# %%
plt.plot(test1['X'][:],test1['PRS'][:,0,0])
plt.plot(test1['X'][:],test1['PRS'][:,0,1])
#plt.plot(test1['X'][:],test1['TMP'][:,0,-1])
plt.yscale('log')

# %%
plt.plot(test1['X'][:],test1['RHO'][:,0,0])
plt.plot(test1['X'][:],test1['RHO'][:,0,1])
#plt.plot(test1['X'][:],test1['TMP'][:,0,-1])
plt.yscale('log')

# %%
importlib.reload(f)
f.pprofile(test1,'TMP',tdk='yrs',steps=3,yprop=0,ix=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-cf72518b5a06> in <module>
#       1 importlib.reload(f)
# ----> 2 f.pprofile(test1,'TMP',tdk='yrs',steps=3,yprop=0,ix=0)
#
# ~/astro/JetCloudSim/Notebooks/f.py in pprofile(c, VAR, VAR2, steps, itlim, ix, yprop, tdk, yl, yl2, alpha, alpha2, sc1, sc2, secopt, Save_Figure, xlim, ylim)
#     245     td= 1e6 if tdk == 'Myrs' else 1e3 if tdk == 'kyrs' else 1.
#     246     for t in T:
# --> 247         ax.plot(c['X'][ix:]*10.,d[yprop,ix:,t],label='{:.1f} {}'.format(c['T'][t]/td,tdk),alpha=alpha)
#     248         if VAR2!=None:
#     249             if secopt=='left':
#
# ~/.local/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1783                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1784                         RuntimeWarning, stacklevel=2)
# -> 1785             return func(ax, *args, **kwargs)
#    1786
#    1787         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~/.local/lib/python3.6/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, *args, **kwargs)
#    1602         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
#    1603
# -> 1604         for line in self._get_lines(*args, **kwargs):
#    1605             self.add_line(line)
#    1606             lines.append(line)
#
# ~/.local/lib/python3.6/site-packages/matplotlib/axes/_base.py in _grab_next_args(self, *args, **kwargs)
#     391                 this += args[0],
#     392                 args = args[1:]
# --> 393             yield from self._plot_args(this, kwargs)
#     394
#     395
#
# ~/.local/lib/python3.6/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     368             x, y = index_of(tup[-1])
#     369
# --> 370         x, y = self._xy_from_xy(x, y)
#     371
#     372         if self.command == 'plot':
#
# ~/.local/lib/python3.6/site-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     229         if x.shape[0] != y.shape[0]:
#     230             raise ValueError("x and y must have same first dimension, but "
# --> 231                              "have shapes {} and {}".format(x.shape, y.shape))
#     232         if x.ndim > 2 or y.ndim > 2:
#     233             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (128,) and (256,)
